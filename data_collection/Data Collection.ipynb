# %% [markdown]
# ### Workshop: 2. Data Collection

# %% [markdown]
# ## What is the goal of the project

# %% [markdown]
# 1. **How engaged are students?**
# 2. *How many years do they stay in an organization?*
# 3. *Who typically leads a student organization?* Are there any patterns?
# 4. *Is there a relationship between the number of organizations a student is involved with and GPA?*
# 5. *Can this inform us about student stress?*
# 6. *To what extent do organizations focus on equity and inclusion?*
# 7. *For students not involved in organizations, what does their university engagement look like?*
# 8. *How do students define their own university engagement?*

# %% [markdown]
# ## Solutions:
#    1. Collected Data *https://drive.google.com/file/d/1n2Ga-OyA4WOPLp_IZb-emkghfoOY0qS6/view?usp=sharing*
#    2. **Data Collection (e.g., Survey, Questionnaire)**

# %%
import pandas as pd
data = pd.read_csv("Engagement.csv")

# %%
data.describe()
# Out:
#          DateCreated    Status                     OrganizationType  \
# count            644       644                                  644
# unique           629         1                                    3
# top     5/1/20 12:13  Approved  Contracted Independent Organization
# freq               2       644                                  529
#
#                      Name ShortName      Affiliated School  \
# count                 644       581                    653
# unique                643       575                     20
# top     Virginia Di Shaan       MSS  No affiliated schools
# freq                    2         2                    321
#
#                              Membership Type  \
# count                                    648
# unique                                     7
# top     Predominantly Undergraduate Students
# freq                                     381
#
#        Approximate year the organization was founded at UVA  \
# ...

# %%
list(data.columns)
# Out:
# ['DateCreated',
#  'Status',
#  'OrganizationType',
#  'Name',
#  'ShortName',
#  'Affiliated School',
#  'Membership Type',
#  'Approximate year the organization was founded at UVA',
#  'Please list 3-5 Primary Events/Programs that your CIO hosts each year. If you do not have annual recurring events,please list some of the events/programs you hosted this past year.',
#  'Total number of Members (approximate)',
#  'Approximate membership dues per academic year (if zero,please write "zero")',
#  "Approximately,how much money do members spend out of pocket per academic year,not including dues,for your CIO activities? (write the number,don't include $)",
#  'Please list your primary sources of funding (SAF,fundraisers,national organizations,alumni,departments,etc.)',
#  'Not including SAF,approximately how much money does your organization fundraise per academic year?',
#  'DoesÂ\xa0this organization require an application or an interview/audition process to join?',
# ...

# %%
data.OrganizationType.value_counts()
# Out:
# Contracted Independent Organization    529
# CIO - Law                               66
# CIO - Darden                            49
# Name: OrganizationType, dtype: int64

# %%
data['Total number of Members (approximate)'].value_counts()
# Out:
# 30                   64
# 20                   62
# 50                   60
# 15                   40
# 40                   35
#                      ..
# 35 (>250 members)     1
# 146                   1
# 1000                  1
# 5                     1
# 30-35                 1
# Name: Total number of Members (approximate), Length: 107, dtype: int64

# %%
data.columns
# Out:
# Index(['DateCreated', 'Status', 'OrganizationType', 'Name', 'ShortName',
#        'Affiliated School', 'Membership Type',
#        'Approximate year the organization was founded at UVA',
#        'Please list 3-5 Primary Events/Programs that your CIO hosts each year. If you do not have annual recurring events,please list some of the events/programs you hosted this past year.',
#        'Total number of Members (approximate)',
#        'Approximate membership dues per academic year (if zero,please write "zero")',
#        'Approximately,how much money do members spend out of pocket per academic year,not including dues,for your CIO activities? (write the number,don't include $)',
#        'Please list your primary sources of funding (SAF,fundraisers,national organizations,alumni,departments,etc.)',
#        'Not including SAF,approximately how much money does your organization fundraise per academic year?',
# ...

# %% [markdown]
# ### Survey must be:
#
# *Whatever exists at all exists in some amount. To know it thoroughly involves knowing its quantity as well as its quality. —Edward Thorndike*
#
# Psychological phenomena investigated in psychology are often latent, in that the constructs of interest are typically unobservable (e.g., attitudes). Measures are developed and employed in the pursuit of studying these phenomena.
#
#    - For instance, the construct of life satisfaction is often measured by the 5-item Satisfaction with Life Scale (Diener, Emmons, Larsen, & Griffin, 1985).
#
# After responses to these items are collected and scored, these scores are taken to represent the construct of life satisfaction in data analysis and in the interpre- tations from analysis.

# %% [markdown]
# ### There are following types of questionnaires:
#  1. Computer questionnaire.
#  2. Telephone questionnaire.
#  3. In-house survey.
#  4. Mail Questionnaire.
#
# ### Questionnaires can include the following types of questions:
#  1. Open question questionnaires.
#  2. Multiple choice questions.
#  3. Dichotomous Questions.
#  4. Scaling Questions.

# %% [markdown]
# ## Let's construct a questionnaire for our project

# %% [markdown]
# - What data do we have?
# - Which features/data are we missing?

# %% [markdown]
# ### **How engaged are students?**
# What is the definition of engagement?
# Let's assume we're interested in the number of years that a member stay at an organization. So, we can ask this question from our _audiances_.
# To do so, we need something interesting which can be **Qualtrics**!!
#
# Ready for a real work:
#
#
# 1. More info about Qualtrics:
#
#     https://data.library.virginia.edu/research-software/qualtrics-research-suite/
#
#
# 2. Login to Qualtrics through UVa:
#
#     https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=&cad=rja&uact=8&ved=2ahUKEwiLhtWM1_jrAhV2mXIEHZ4XBXsQFjAAegQIARAB&url=https%3A%2F%2Fvirginia.qualtrics.com%2F&usg=AOvVaw1dfFJmkZ8Sf2TIv6Eg_GEj
#
#     - Example: https://qtrial2019q4az1.az1.qualtrics.com/jfe/form/SV_eFNyTSjVhz8CsZf

# %%
responses = pd.read_csv("response.csv")

# %%
responses.describe()
# Out:
#                   StartDate              EndDate      Status        IPAddress  \
# count                     7                    7           7                7
# unique                    7                    7           3                4
# top     2020-09-20 16:32:56  2020-09-20 16:41:42  IP Address  199.111.224.177
# freq                      1                    1           5                4
#
#        Progress  Duration (in seconds) Finished         RecordedDate  \
# count         7                      7        7                    7
# unique        3                      7        3                    7
# top         100  Duration (in seconds)     True  2020-09-20 16:35:23
# freq          5                      1        5                    1
#
#                ResponseId                 RecipientLastName  ...  \
# count                   7                                 2  ...
# unique                  7                                 2  ...
# ...

# %%
responses.head(5)
# Out:
#                                            StartDate  \
# 0                                         Start Date
# 1  {"ImportId":"startDate","timeZone":"America/De...
# 2                                2020-09-20 16:32:56
# 3                                2020-09-20 16:34:38
# 4                                2020-09-20 16:35:13
#
#                                              EndDate                 Status  \
# 0                                           End Date          Response Type
# 1  {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
# 2                                2020-09-20 16:33:19             IP Address
# 3                                2020-09-20 16:34:46             IP Address
# 4                                2020-09-20 16:35:23             IP Address
#
#                   IPAddress                 Progress    Duration (in seconds)  \
# 0                IP Address                 Progress    Duration (in seconds)
# ...
